# %% [markdown]
# # Pandas Basics

# %%
import pandas as pd

# %%
df = pd.read_csv('IMDb movies.csv')

# %%
df.head(2)
# Out:
#   imdb_title_id                        title               original_title  \
# 0     tt0000574  The Story of the Kelly Gang  The Story of the Kelly Gang
# 1     tt0001892               Den sorte drøm               Den sorte drøm
#
#    year date_published                    genre  duration           country  \
# 0  1906     1906-12-26  Biography, Crime, Drama        70         Australia
# 1  1911     1911-08-19                    Drama        53  Germany, Denmark
#
#   language      director  ...  \
# 0      NaN  Charles Tait  ...
# 1      NaN     Urban Gad  ...
#
#                                               actors  \
# 0  Elizabeth Tait, John Tait, Norman Campbell, Be...
# 1  Asta Nielsen, Valdemar Psilander, Gunnar Helse...
#
#                                          description avg_vote votes  budget  \
# 0  True story of notorious Australian outlaw Ned ...      6.1   537  $ 2250
# 1  Two men of high rank are both wooing the beaut...      5.9   171     NaN
#
#    usa_gross_income worlwide_gross_income metascore reviews_from_users  \
# 0               NaN                   NaN       NaN                7.0
# 1               NaN                   NaN       NaN                4.0
#
#    reviews_from_critics
# 0                   7.0
# 1                   2.0
#
# [2 rows x 22 columns]

# %%
df.tail(2)
# Out:
#       imdb_title_id                      title             original_title  \
# 81271     tt9911774  Padmavyuhathile Abhimanyu  Padmavyuhathile Abhimanyu
# 81272     tt9914286          Sokagin Çocuklari          Sokagin Çocuklari
#
#        year date_published          genre  duration country   language  \
# 81271  2019     2019-03-08          Drama       130   India  Malayalam
# 81272  2019     2019-03-15  Drama, Family        98  Turkey    Turkish
#
#                 director  ...  \
# 81271    Vineesh Aaradya  ...
# 81272  Ahmet Faik Akinci  ...
#
#                                                   actors description avg_vote  \
# 81271  Anoop Chandran, Indrans, Sona Nair, Simon Brit...         NaN      8.4
# 81272  Ahmet Faik Akinci, Belma Mamati, Metin Keçeci,...         NaN      7.2
#
#       votes  budget  usa_gross_income worlwide_gross_income metascore  \
# 81271   369     NaN               NaN                   NaN       NaN
# 81272   190     NaN               NaN                $ 2833       NaN
#
#       reviews_from_users  reviews_from_critics
# 81271                NaN                   NaN
# 81272                NaN                   NaN
#
# [2 rows x 22 columns]

# %%
df.shape
# Out:
# (81273, 22)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 81273 entries, 0 to 81272
# Data columns (total 22 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   imdb_title_id          81273 non-null  object
#  1   title                  81273 non-null  object
#  2   original_title         81273 non-null  object
#  3   year                   81273 non-null  int64
#  4   date_published         81273 non-null  object
#  5   genre                  81273 non-null  object
#  6   duration               81273 non-null  int64
#  7   country                81234 non-null  object
#  8   language               80518 non-null  object
#  9   director               81200 non-null  object
#  10  writer                 79780 non-null  object
#  11  production_company     76948 non-null  object
#  12  actors                 81207 non-null  object
#  13  description            78843 non-null  object
#  14  avg_vote               81273 non-null  float64
#  15  votes                  81273 non-null  int64
#  16  budget                 22804 non-null  object
#  17  usa_gross_income       15094 non-null  object
#  18  worlwide_gross_income  29892 non-null  object
#  19  metascore              12722 non-null  float64
#  20  reviews_from_users     74196 non-null  float64
#  21  reviews_from_critics   70286 non-null  float64
# dtypes: float64(4), int64(3), object(15)
# memory usage: 13.6+ MB

# %%
df.describe()
# Out:
#                year      duration      avg_vote         votes     metascore  \
# count  81273.000000  81273.000000  81273.000000  8.127300e+04  12722.000000
# mean    1993.007210    100.565981      5.926587  9.421771e+03     55.762695
# std       23.992284     25.320189      1.243315  5.220245e+04     17.757453
# min     1906.000000     40.000000      1.000000  9.900000e+01      1.000000
# 25%     1979.000000     88.000000      5.200000  2.060000e+02     43.000000
# 50%     2002.000000     96.000000      6.100000  4.950000e+02     56.000000
# 75%     2012.000000    108.000000      6.800000  1.865000e+03     69.000000
# max     2019.000000   3360.000000     10.000000  2.159628e+06    100.000000
#
#        reviews_from_users  reviews_from_critics
# count        74196.000000          70286.000000
# mean            43.753194             27.992758
# std            159.903568             58.708764
# min              1.000000              1.000000
# 25%              4.000000              3.000000
# 50%              9.000000              8.000000
# 75%             26.000000             24.000000
# max           8302.000000            987.000000

# %%
df.describe(include='all')
# Out:
#        imdb_title_id  title original_title          year date_published  \
# count          81273  81273          81273  81273.000000          81273
# unique         81273  76618          76631           NaN          21087
# top        tt0116635   Anna           Anna           NaN           2010
# freq               1      9              9           NaN            111
# mean             NaN    NaN            NaN   1993.007210            NaN
# std              NaN    NaN            NaN     23.992284            NaN
# min              NaN    NaN            NaN   1906.000000            NaN
# 25%              NaN    NaN            NaN   1979.000000            NaN
# 50%              NaN    NaN            NaN   2002.000000            NaN
# 75%              NaN    NaN            NaN   2012.000000            NaN
# max              NaN    NaN            NaN   2019.000000            NaN
#
#         genre      duration country language        director  ...  \
# count   81273  81273.000000   81234    80518           81200  ...
# unique   1264           NaN    4632     4251           32544  ...
# top     Drama           NaN     USA  English  Michael Curtiz  ...
# freq    11809           NaN   27490    34519              86  ...
# mean      NaN    100.565981     NaN      NaN             NaN  ...
# std       NaN     25.320189     NaN      NaN             NaN  ...
# min       NaN     40.000000     NaN      NaN             NaN  ...
# 25%       NaN     88.000000     NaN      NaN             NaN  ...
# 50%       NaN     96.000000     NaN      NaN             NaN  ...
# 75%       NaN    108.000000     NaN      NaN             NaN  ...
# max       NaN   3360.000000     NaN      NaN             NaN  ...
#
#                                                    actors   description  \
# count                                               81207         78843
# unique                                              81159         78727
# top     Nobuyo Ôyama, Noriko Ohara, Michiko Nomura, Ka...  The story of
# freq                                                   13            11
# mean                                                  NaN           NaN
# std                                                   NaN           NaN
# min                                                   NaN           NaN
# 25%                                                   NaN           NaN
# 50%                                                   NaN           NaN
# 75%                                                   NaN           NaN
# max                                                   NaN           NaN
#
#             avg_vote         votes     budget  usa_gross_income  \
# count   81273.000000  8.127300e+04      22804             15094
# unique           NaN           NaN       4425             14648
# top              NaN           NaN  $ 1000000         $ 1000000
# freq             NaN           NaN        731                19
# mean        5.926587  9.421771e+03        NaN               NaN
# std         1.243315  5.220245e+04        NaN               NaN
# min         1.000000  9.900000e+01        NaN               NaN
# 25%         5.200000  2.060000e+02        NaN               NaN
# 50%         6.100000  4.950000e+02        NaN               NaN
# 75%         6.800000  1.865000e+03        NaN               NaN
# max        10.000000  2.159628e+06        NaN               NaN
#
#        worlwide_gross_income     metascore reviews_from_users  \
# count                  29892  12722.000000       74196.000000
# unique                 29378           NaN                NaN
# top                   $ 8144           NaN                NaN
# freq                      16           NaN                NaN
# mean                     NaN     55.762695          43.753194
# std                      NaN     17.757453         159.903568
# min                      NaN      1.000000           1.000000
# 25%                      NaN     43.000000           4.000000
# 50%                      NaN     56.000000           9.000000
# 75%                      NaN     69.000000          26.000000
# max                      NaN    100.000000        8302.000000
#
#         reviews_from_critics
# count           70286.000000
# unique                   NaN
# top                      NaN
# freq                     NaN
# mean               27.992758
# std                58.708764
# min                 1.000000
# 25%                 3.000000
# 50%                 8.000000
# 75%                24.000000
# max               987.000000
#
# [11 rows x 22 columns]

# %%
df.year
# Out:
# 0        1906
# 1        1911
# 2        1912
# 3        1911
# 4        1912
#          ...
# 81268    2019
# 81269    2019
# 81270    2019
# 81271    2019
# 81272    2019
# Name: year, Length: 81273, dtype: int64

# %%
df['year']
# Out:
# 0        1906
# 1        1911
# 2        1912
# 3        1911
# 4        1912
#          ...
# 81268    2019
# 81269    2019
# 81270    2019
# 81271    2019
# 81272    2019
# Name: year, Length: 81273, dtype: int64

# %%
df['year'].value_counts()
# Out:
# 2017    3106
# 2016    3033
# 2015    2903
# 2018    2880
# 2014    2851
#         ...
# 1915      21
# 1913      13
# 1912       5
# 1911       4
# 1906       1
# Name: year, Length: 110, dtype: int64

# %%
df.year.max()
# Out:
# 2019

# %%
df.year.min()
# Out:
# 1906

# %%
df.year.std()
# Out:
# 23.992283867737942

# %%
df.year.var()
# Out:
# 575.6296851901183

# %%
df.year.count()
# Out:
# 81273

# %%
df.year.mean()
# Out:
# 1993.0072102666322

# %%
df.year.median()
# Out:
# 2002.0

# %%
df.columns.to_list()
# Out:
# ['imdb_title_id',
#  'title',
#  'original_title',
#  'year',
#  'date_published',
#  'genre',
#  'duration',
#  'country',
#  'language',
#  'director',
#  'writer',
#  'production_company',
#  'actors',
#  'description',
#  'avg_vote',
#  'votes',
#  'budget',
#  'usa_gross_income',
#  'worlwide_gross_income',
#  'metascore',
#  'reviews_from_users',
#  'reviews_from_critics']

# %%
df[['title','year','votes']]
# Out:
#                                                    title  year  votes
# 0                            The Story of the Kelly Gang  1906    537
# 1                                         Den sorte drøm  1911    171
# 2                                              Cleopatra  1912    420
# 3                                              L'Inferno  1911   2019
# 4      From the Manger to the Cross; or, Jesus of Naz...  1912    438
# ...                                                  ...   ...    ...
# 81268                                             Jessie  2019    219
# 81269                                              Ottam  2019    510
# 81270                                          Pengalila  2019    604
# 81271                          Padmavyuhathile Abhimanyu  2019    369
# 81272                                  Sokagin Çocuklari  2019    190
#
# [81273 rows x 3 columns]

# %%
df = df[['title','year','votes']]


df
# Out:
#                                                    title  year  votes
# 0                            The Story of the Kelly Gang  1906    537
# 1                                         Den sorte drøm  1911    171
# 2                                              Cleopatra  1912    420
# 3                                              L'Inferno  1911   2019
# 4      From the Manger to the Cross; or, Jesus of Naz...  1912    438
# ...                                                  ...   ...    ...
# 81268                                             Jessie  2019    219
# 81269                                              Ottam  2019    510
# 81270                                          Pengalila  2019    604
# 81271                          Padmavyuhathile Abhimanyu  2019    369
# 81272                                  Sokagin Çocuklari  2019    190
#
# [81273 rows x 3 columns]

# %%
df.title.iloc[2]
# Out:
# 'Cleopatra'

# %%
df.iloc[2]
# Out:
# title    Cleopatra
# year          1912
# votes          420
# Name: 2, dtype: object

# %%
df.title.iloc[0:5]
# Out:
# 0                          The Story of the Kelly Gang
# 1                                       Den sorte drøm
# 2                                            Cleopatra
# 3                                            L'Inferno
# 4    From the Manger to the Cross; or, Jesus of Naz...
# Name: title, dtype: object

# %%
df.title.iloc[-3:]
# Out:
# 81270                    Pengalila
# 81271    Padmavyuhathile Abhimanyu
# 81272            Sokagin Çocuklari
# Name: title, dtype: object

# %%
df.iloc[-3:]
# Out:
#                            title  year  votes
# 81270                  Pengalila  2019    604
# 81271  Padmavyuhathile Abhimanyu  2019    369
# 81272          Sokagin Çocuklari  2019    190

# %%
df.iloc[:,1]
# Out:
# 0        1906
# 1        1911
# 2        1912
# 3        1911
# 4        1912
#          ...
# 81268    2019
# 81269    2019
# 81270    2019
# 81271    2019
# 81272    2019
# Name: year, Length: 81273, dtype: int64

# %%
df.iloc[:,[0,2]]
# Out:
#                                                    title  votes
# 0                            The Story of the Kelly Gang    537
# 1                                         Den sorte drøm    171
# 2                                              Cleopatra    420
# 3                                              L'Inferno   2019
# 4      From the Manger to the Cross; or, Jesus of Naz...    438
# ...                                                  ...    ...
# 81268                                             Jessie    219
# 81269                                              Ottam    510
# 81270                                          Pengalila    604
# 81271                          Padmavyuhathile Abhimanyu    369
# 81272                                  Sokagin Çocuklari    190
#
# [81273 rows x 2 columns]

# %%
df.iloc[[0,2,3,4],:]
# Out:
#                                                title  year  votes
# 0                        The Story of the Kelly Gang  1906    537
# 2                                          Cleopatra  1912    420
# 3                                          L'Inferno  1911   2019
# 4  From the Manger to the Cross; or, Jesus of Naz...  1912    438

# %%
df.iloc[4,1]
# Out:
# 1912

# %%
df
# Out:
#                                                    title  year  votes
# 0                            The Story of the Kelly Gang  1906    537
# 1                                         Den sorte drøm  1911    171
# 2                                              Cleopatra  1912    420
# 3                                              L'Inferno  1911   2019
# 4      From the Manger to the Cross; or, Jesus of Naz...  1912    438
# ...                                                  ...   ...    ...
# 81268                                             Jessie  2019    219
# 81269                                              Ottam  2019    510
# 81270                                          Pengalila  2019    604
# 81271                          Padmavyuhathile Abhimanyu  2019    369
# 81272                                  Sokagin Çocuklari  2019    190
#
# [81273 rows x 3 columns]

# %%
df.columns = ['title_new','year_new','votes_new']
df
# Out:
#                                                title_new  year_new  votes_new
# 0                            The Story of the Kelly Gang      1906        537
# 1                                         Den sorte drøm      1911        171
# 2                                              Cleopatra      1912        420
# 3                                              L'Inferno      1911       2019
# 4      From the Manger to the Cross; or, Jesus of Naz...      1912        438
# ...                                                  ...       ...        ...
# 81268                                             Jessie      2019        219
# 81269                                              Ottam      2019        510
# 81270                                          Pengalila      2019        604
# 81271                          Padmavyuhathile Abhimanyu      2019        369
# 81272                                  Sokagin Çocuklari      2019        190
#
# [81273 rows x 3 columns]

# %%
df.columns = ['title','year','votes']
df
# Out:
#                                                    title  year  votes
# 0                            The Story of the Kelly Gang  1906    537
# 1                                         Den sorte drøm  1911    171
# 2                                              Cleopatra  1912    420
# 3                                              L'Inferno  1911   2019
# 4      From the Manger to the Cross; or, Jesus of Naz...  1912    438
# ...                                                  ...   ...    ...
# 81268                                             Jessie  2019    219
# 81269                                              Ottam  2019    510
# 81270                                          Pengalila  2019    604
# 81271                          Padmavyuhathile Abhimanyu  2019    369
# 81272                                  Sokagin Çocuklari  2019    190
#
# [81273 rows x 3 columns]

# %%
df.year.value_counts()
# Out:
# 2017    3106
# 2016    3033
# 2015    2903
# 2018    2880
# 2014    2851
#         ...
# 1915      21
# 1913      13
# 1912       5
# 1911       4
# 1906       1
# Name: year, Length: 110, dtype: int64

# %%
df = pd.read_csv('IMDb movies.csv')
df.head(3)
# Out:
#   imdb_title_id                        title               original_title  \
# 0     tt0000574  The Story of the Kelly Gang  The Story of the Kelly Gang
# 1     tt0001892               Den sorte drøm               Den sorte drøm
# 2     tt0002101                    Cleopatra                    Cleopatra
#
#    year date_published                    genre  duration           country  \
# 0  1906     1906-12-26  Biography, Crime, Drama        70         Australia
# 1  1911     1911-08-19                    Drama        53  Germany, Denmark
# 2  1912     1912-11-13           Drama, History       100               USA
#
#   language            director  ...  \
# 0      NaN        Charles Tait  ...
# 1      NaN           Urban Gad  ...
# 2  English  Charles L. Gaskill  ...
#
#                                               actors  \
# 0  Elizabeth Tait, John Tait, Norman Campbell, Be...
# 1  Asta Nielsen, Valdemar Psilander, Gunnar Helse...
# 2  Helen Gardner, Pearl Sindelar, Miss Fielding, ...
#
#                                          description avg_vote votes   budget  \
# 0  True story of notorious Australian outlaw Ned ...      6.1   537   $ 2250
# 1  Two men of high rank are both wooing the beaut...      5.9   171      NaN
# 2  The fabled queen of Egypt's affair with Roman ...      5.2   420  $ 45000
#
#    usa_gross_income worlwide_gross_income metascore reviews_from_users  \
# 0               NaN                   NaN       NaN                7.0
# 1               NaN                   NaN       NaN                4.0
# 2               NaN                   NaN       NaN               24.0
#
#    reviews_from_critics
# 0                   7.0
# 1                   2.0
# 2                   3.0
#
# [3 rows x 22 columns]

# %%
df.dropna().head(3)
# Out:
#      imdb_title_id         title original_title  year date_published  \
# 488      tt0017136    Metropolis     Metropolis  1927     1927-02-06
# 1005     tt0021749   City Lights    City Lights  1931     1931-08-21
# 2336     tt0027977  Modern Times   Modern Times  1936     1936-10-16
#
#                        genre  duration  country language         director  \
# 488            Drama, Sci-Fi       153  Germany   German       Fritz Lang
# 1005  Comedy, Drama, Romance        87      USA  English  Charles Chaplin
# 2336   Comedy, Drama, Family        87      USA  English  Charles Chaplin
#
#       ...                                             actors  \
# 488   ...  Alfred Abel, Gustav Fröhlich, Rudolf Klein-Rog...
# 1005  ...  Virginia Cherrill, Florence Lee, Harry Myers, ...
# 2336  ...  Charles Chaplin, Paulette Goddard, Henry Bergm...
#
#                                             description avg_vote   votes  \
# 488   In a futuristic city sharply divided between t...      8.3  148396
# 1005  With the aid of a wealthy erratic tippler, a d...      8.5  152716
# 2336  The Tramp struggles to live in modern industri...      8.5  197969
#
#            budget  usa_gross_income worlwide_gross_income metascore  \
# 488   DEM 6000000         $ 1236166             $ 1349711      98.0
# 1005    $ 1500000           $ 19181               $ 32609      99.0
# 2336    $ 1500000          $ 163577              $ 445226      96.0
#
#      reviews_from_users  reviews_from_critics
# 488               471.0                 194.0
# 1005              270.0                 120.0
# 2336              262.0                 146.0
#
# [3 rows x 22 columns]

# %%
# drop all rows with missing valuea 
df.dropna().head(3)
# Out:
#      imdb_title_id         title original_title  year date_published  \
# 488      tt0017136    Metropolis     Metropolis  1927     1927-02-06
# 1005     tt0021749   City Lights    City Lights  1931     1931-08-21
# 2336     tt0027977  Modern Times   Modern Times  1936     1936-10-16
#
#                        genre  duration  country language         director  \
# 488            Drama, Sci-Fi       153  Germany   German       Fritz Lang
# 1005  Comedy, Drama, Romance        87      USA  English  Charles Chaplin
# 2336   Comedy, Drama, Family        87      USA  English  Charles Chaplin
#
#       ...                                             actors  \
# 488   ...  Alfred Abel, Gustav Fröhlich, Rudolf Klein-Rog...
# 1005  ...  Virginia Cherrill, Florence Lee, Harry Myers, ...
# 2336  ...  Charles Chaplin, Paulette Goddard, Henry Bergm...
#
#                                             description avg_vote   votes  \
# 488   In a futuristic city sharply divided between t...      8.3  148396
# 1005  With the aid of a wealthy erratic tippler, a d...      8.5  152716
# 2336  The Tramp struggles to live in modern industri...      8.5  197969
#
#            budget  usa_gross_income worlwide_gross_income metascore  \
# 488   DEM 6000000         $ 1236166             $ 1349711      98.0
# 1005    $ 1500000           $ 19181               $ 32609      99.0
# 2336    $ 1500000          $ 163577              $ 445226      96.0
#
#      reviews_from_users  reviews_from_critics
# 488               471.0                 194.0
# 1005              270.0                 120.0
# 2336              262.0                 146.0
#
# [3 rows x 22 columns]

# %%
# drop all columns with missing values 
df.dropna(axis='columns')
# Out:
#       imdb_title_id                                              title  \
# 0         tt0000574                        The Story of the Kelly Gang
# 1         tt0001892                                     Den sorte drøm
# 2         tt0002101                                          Cleopatra
# 3         tt0002130                                          L'Inferno
# 4         tt0002199  From the Manger to the Cross; or, Jesus of Naz...
# ...             ...                                                ...
# 81268     tt9903716                                             Jessie
# 81269     tt9905412                                              Ottam
# 81270     tt9905462                                          Pengalila
# 81271     tt9911774                          Padmavyuhathile Abhimanyu
# 81272     tt9914286                                  Sokagin Çocuklari
#
#                                           original_title  year date_published  \
# 0                            The Story of the Kelly Gang  1906     1906-12-26
# 1                                         Den sorte drøm  1911     1911-08-19
# 2                                              Cleopatra  1912     1912-11-13
# 3                                              L'Inferno  1911     1911-03-06
# 4      From the Manger to the Cross; or, Jesus of Naz...  1912           1913
# ...                                                  ...   ...            ...
# 81268                                             Jessie  2019     2019-03-15
# 81269                                              Ottam  2019     2019-03-08
# 81270                                          Pengalila  2019     2019-03-08
# 81271                          Padmavyuhathile Abhimanyu  2019     2019-03-08
# 81272                                  Sokagin Çocuklari  2019     2019-03-15
#
#                            genre  duration  avg_vote  votes
# 0        Biography, Crime, Drama        70       6.1    537
# 1                          Drama        53       5.9    171
# 2                 Drama, History       100       5.2    420
# 3      Adventure, Drama, Fantasy        68       7.0   2019
# 4               Biography, Drama        60       5.7    438
# ...                          ...       ...       ...    ...
# 81268           Horror, Thriller       106       7.2    219
# 81269                      Drama       120       7.8    510
# 81270                      Drama       111       8.4    604
# 81271                      Drama       130       8.4    369
# 81272              Drama, Family        98       7.2    190
#
# [81273 rows x 9 columns]

# %%
# Drop missing values from specified columns 
df.dropna(subset=['metascore','budget']).head(2)
# Out:
#     imdb_title_id                                             title  \
# 73      tt0006864  Intolerance: Love's Struggle Throughout the Ages
# 488     tt0017136                                        Metropolis
#
#                                        original_title  year date_published  \
# 73   Intolerance: Love's Struggle Throughout the Ages  1916     1918-02-24
# 488                                        Metropolis  1927     1927-02-06
#
#               genre  duration  country language       director  ...  \
# 73   Drama, History       163      USA      NaN  D.W. Griffith  ...
# 488   Drama, Sci-Fi       153  Germany   German     Fritz Lang  ...
#
#                                                 actors  \
# 73   Lillian Gish, Mae Marsh, Robert Harron, F.A. T...
# 488  Alfred Abel, Gustav Fröhlich, Rudolf Klein-Rog...
#
#                                            description avg_vote   votes  \
# 73   The story of a poor young woman, separated by ...      7.8   13116
# 488  In a futuristic city sharply divided between t...      8.3  148396
#
#           budget  usa_gross_income worlwide_gross_income metascore  \
# 73      $ 385907               NaN                   NaN      93.0
# 488  DEM 6000000         $ 1236166             $ 1349711      98.0
#
#     reviews_from_users  reviews_from_critics
# 73               105.0                  77.0
# 488              471.0                 194.0
#
# [2 rows x 22 columns]

# %%
df.dropna(axis='columns', inplace = True)
df
# Out:
#       imdb_title_id                                              title  \
# 0         tt0000574                        The Story of the Kelly Gang
# 1         tt0001892                                     Den sorte drøm
# 2         tt0002101                                          Cleopatra
# 3         tt0002130                                          L'Inferno
# 4         tt0002199  From the Manger to the Cross; or, Jesus of Naz...
# ...             ...                                                ...
# 81268     tt9903716                                             Jessie
# 81269     tt9905412                                              Ottam
# 81270     tt9905462                                          Pengalila
# 81271     tt9911774                          Padmavyuhathile Abhimanyu
# 81272     tt9914286                                  Sokagin Çocuklari
#
#                                           original_title  year date_published  \
# 0                            The Story of the Kelly Gang  1906     1906-12-26
# 1                                         Den sorte drøm  1911     1911-08-19
# 2                                              Cleopatra  1912     1912-11-13
# 3                                              L'Inferno  1911     1911-03-06
# 4      From the Manger to the Cross; or, Jesus of Naz...  1912           1913
# ...                                                  ...   ...            ...
# 81268                                             Jessie  2019     2019-03-15
# 81269                                              Ottam  2019     2019-03-08
# 81270                                          Pengalila  2019     2019-03-08
# 81271                          Padmavyuhathile Abhimanyu  2019     2019-03-08
# 81272                                  Sokagin Çocuklari  2019     2019-03-15
#
#                            genre  duration  avg_vote  votes
# 0        Biography, Crime, Drama        70       6.1    537
# 1                          Drama        53       5.9    171
# 2                 Drama, History       100       5.2    420
# 3      Adventure, Drama, Fantasy        68       7.0   2019
# 4               Biography, Drama        60       5.7    438
# ...                          ...       ...       ...    ...
# 81268           Horror, Thriller       106       7.2    219
# 81269                      Drama       120       7.8    510
# 81270                      Drama       111       8.4    604
# 81271                      Drama       130       8.4    369
# 81272              Drama, Family        98       7.2    190
#
# [81273 rows x 9 columns]

# %%
df = pd.read_csv('IMDb movies.csv')
df.head(3)
# Out:
#   imdb_title_id                        title               original_title  \
# 0     tt0000574  The Story of the Kelly Gang  The Story of the Kelly Gang
# 1     tt0001892               Den sorte drøm               Den sorte drøm
# 2     tt0002101                    Cleopatra                    Cleopatra
#
#    year date_published                    genre  duration           country  \
# 0  1906     1906-12-26  Biography, Crime, Drama        70         Australia
# 1  1911     1911-08-19                    Drama        53  Germany, Denmark
# 2  1912     1912-11-13           Drama, History       100               USA
#
#   language            director  ...  \
# 0      NaN        Charles Tait  ...
# 1      NaN           Urban Gad  ...
# 2  English  Charles L. Gaskill  ...
#
#                                               actors  \
# 0  Elizabeth Tait, John Tait, Norman Campbell, Be...
# 1  Asta Nielsen, Valdemar Psilander, Gunnar Helse...
# 2  Helen Gardner, Pearl Sindelar, Miss Fielding, ...
#
#                                          description avg_vote votes   budget  \
# 0  True story of notorious Australian outlaw Ned ...      6.1   537   $ 2250
# 1  Two men of high rank are both wooing the beaut...      5.9   171      NaN
# 2  The fabled queen of Egypt's affair with Roman ...      5.2   420  $ 45000
#
#    usa_gross_income worlwide_gross_income metascore reviews_from_users  \
# 0               NaN                   NaN       NaN                7.0
# 1               NaN                   NaN       NaN                4.0
# 2               NaN                   NaN       NaN               24.0
#
#    reviews_from_critics
# 0                   7.0
# 1                   2.0
# 2                   3.0
#
# [3 rows x 22 columns]

# %%
df['budget'].fillna(0, inplace=True)
df.head(3)
# Out:
#   imdb_title_id                        title               original_title  \
# 0     tt0000574  The Story of the Kelly Gang  The Story of the Kelly Gang
# 1     tt0001892               Den sorte drøm               Den sorte drøm
# 2     tt0002101                    Cleopatra                    Cleopatra
#
#    year date_published                    genre  duration           country  \
# 0  1906     1906-12-26  Biography, Crime, Drama        70         Australia
# 1  1911     1911-08-19                    Drama        53  Germany, Denmark
# 2  1912     1912-11-13           Drama, History       100               USA
#
#   language            director  ...  \
# 0      NaN        Charles Tait  ...
# 1      NaN           Urban Gad  ...
# 2  English  Charles L. Gaskill  ...
#
#                                               actors  \
# 0  Elizabeth Tait, John Tait, Norman Campbell, Be...
# 1  Asta Nielsen, Valdemar Psilander, Gunnar Helse...
# 2  Helen Gardner, Pearl Sindelar, Miss Fielding, ...
#
#                                          description avg_vote votes   budget  \
# 0  True story of notorious Australian outlaw Ned ...      6.1   537   $ 2250
# 1  Two men of high rank are both wooing the beaut...      5.9   171        0
# 2  The fabled queen of Egypt's affair with Roman ...      5.2   420  $ 45000
#
#    usa_gross_income worlwide_gross_income metascore reviews_from_users  \
# 0               NaN                   NaN       NaN                7.0
# 1               NaN                   NaN       NaN                4.0
# 2               NaN                   NaN       NaN               24.0
#
#    reviews_from_critics
# 0                   7.0
# 1                   2.0
# 2                   3.0
#
# [3 rows x 22 columns]
