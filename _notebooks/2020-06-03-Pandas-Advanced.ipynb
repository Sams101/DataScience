# %% [markdown]
# # Pandas Advanced
#
# - toc: true
# - badges: False
# - comments: true
# - author: Sam Treacy
# - categories: [pandas, python, advanced]

# %%
import pandas as pd

# %%
df = pd.read_csv('IMDb movies.csv')

# %%
df.head(2)
# Out:
#   imdb_title_id                        title               original_title  \
# 0     tt0000574  The Story of the Kelly Gang  The Story of the Kelly Gang
# 1     tt0001892               Den sorte drøm               Den sorte drøm
#
#    year date_published                    genre  duration           country  \
# 0  1906     1906-12-26  Biography, Crime, Drama        70         Australia
# 1  1911     1911-08-19                    Drama        53  Germany, Denmark
#
#   language      director  ...  \
# 0      NaN  Charles Tait  ...
# 1      NaN     Urban Gad  ...
#
#                                               actors  \
# 0  Elizabeth Tait, John Tait, Norman Campbell, Be...
# 1  Asta Nielsen, Valdemar Psilander, Gunnar Helse...
#
#                                          description avg_vote votes  budget  \
# 0  True story of notorious Australian outlaw Ned ...      6.1   537  $ 2250
# 1  Two men of high rank are both wooing the beaut...      5.9   171     NaN
#
# ...

# %% [markdown]
# Mass renaming of columns

# %%
df.rename(columns=lambda x: x + '_new').head(2)
# Out:
#   imdb_title_id_new                    title_new           original_title_new  \
# 0         tt0000574  The Story of the Kelly Gang  The Story of the Kelly Gang
# 1         tt0001892               Den sorte drøm               Den sorte drøm
#
#    year_new date_published_new                genre_new  duration_new  \
# 0      1906         1906-12-26  Biography, Crime, Drama            70
# 1      1911         1911-08-19                    Drama            53
#
#         country_new language_new  director_new  ...  \
# 0         Australia          NaN  Charles Tait  ...
# 1  Germany, Denmark          NaN     Urban Gad  ...
#
#                                           actors_new  \
# 0  Elizabeth Tait, John Tait, Norman Campbell, Be...
# 1  Asta Nielsen, Valdemar Psilander, Gunnar Helse...
#
#                                      description_new avg_vote_new votes_new  \
# 0  True story of notorious Australian outlaw Ned ...          6.1       537
# ...

# %%
df.rename(columns=lambda x: x.upper()).head(2)
# Out:
#   IMDB_TITLE_ID                        TITLE               ORIGINAL_TITLE  \
# 0     tt0000574  The Story of the Kelly Gang  The Story of the Kelly Gang
# 1     tt0001892               Den sorte drøm               Den sorte drøm
#
#    YEAR DATE_PUBLISHED                    GENRE  DURATION           COUNTRY  \
# 0  1906     1906-12-26  Biography, Crime, Drama        70         Australia
# 1  1911     1911-08-19                    Drama        53  Germany, Denmark
#
#   LANGUAGE      DIRECTOR  ...  \
# 0      NaN  Charles Tait  ...
# 1      NaN     Urban Gad  ...
#
#                                               ACTORS  \
# 0  Elizabeth Tait, John Tait, Norman Campbell, Be...
# 1  Asta Nielsen, Valdemar Psilander, Gunnar Helse...
#
#                                          DESCRIPTION AVG_VOTE VOTES  BUDGET  \
# 0  True story of notorious Australian outlaw Ned ...      6.1   537  $ 2250
# 1  Two men of high rank are both wooing the beaut...      5.9   171     NaN
#
# ...

# %%
df.rename(columns=lambda x: x.lower()).head(2)
# Out:
#   imdb_title_id                        title               original_title  \
# 0     tt0000574  The Story of the Kelly Gang  The Story of the Kelly Gang
# 1     tt0001892               Den sorte drøm               Den sorte drøm
#
#    year date_published                    genre  duration           country  \
# 0  1906     1906-12-26  Biography, Crime, Drama        70         Australia
# 1  1911     1911-08-19                    Drama        53  Germany, Denmark
#
#   language      director  ...  \
# 0      NaN  Charles Tait  ...
# 1      NaN     Urban Gad  ...
#
#                                               actors  \
# 0  Elizabeth Tait, John Tait, Norman Campbell, Be...
# 1  Asta Nielsen, Valdemar Psilander, Gunnar Helse...
#
#                                          description avg_vote votes  budget  \
# 0  True story of notorious Australian outlaw Ned ...      6.1   537  $ 2250
# 1  Two men of high rank are both wooing the beaut...      5.9   171     NaN
#
# ...

# %%
df.rename(index=lambda x: x * 10).head(2)
# Out:
#    imdb_title_id                        title               original_title  \
# 0      tt0000574  The Story of the Kelly Gang  The Story of the Kelly Gang
# 10     tt0001892               Den sorte drøm               Den sorte drøm
#
#     year date_published                    genre  duration           country  \
# 0   1906     1906-12-26  Biography, Crime, Drama        70         Australia
# 10  1911     1911-08-19                    Drama        53  Germany, Denmark
#
#    language      director  ...  \
# 0       NaN  Charles Tait  ...
# 10      NaN     Urban Gad  ...
#
#                                                actors  \
# 0   Elizabeth Tait, John Tait, Norman Campbell, Be...
# 10  Asta Nielsen, Valdemar Psilander, Gunnar Helse...
#
#                                           description avg_vote votes  budget  \
# 0   True story of notorious Australian outlaw Ned ...      6.1   537  $ 2250
# 10  Two men of high rank are both wooing the beaut...      5.9   171     NaN
#
# ...

# %%
df.rename(index=lambda x: str(x) + '_new' ).head(2)
# Out:
#       imdb_title_id                        title               original_title  \
# 0_new     tt0000574  The Story of the Kelly Gang  The Story of the Kelly Gang
# 1_new     tt0001892               Den sorte drøm               Den sorte drøm
#
#        year date_published                    genre  duration  \
# 0_new  1906     1906-12-26  Biography, Crime, Drama        70
# 1_new  1911     1911-08-19                    Drama        53
#
#                 country language      director  ...  \
# 0_new         Australia      NaN  Charles Tait  ...
# 1_new  Germany, Denmark      NaN     Urban Gad  ...
#
#                                                   actors  \
# 0_new  Elizabeth Tait, John Tait, Norman Campbell, Be...
# 1_new  Asta Nielsen, Valdemar Psilander, Gunnar Helse...
#
#                                              description avg_vote votes  \
# 0_new  True story of notorious Australian outlaw Ned ...      6.1   537
# ...

# %%
new = df.set_index('year').head(3)

# %%
new.sort_index(ascending = False)
# Out:
#      imdb_title_id                        title               original_title  \
# year
# 1912     tt0002101                    Cleopatra                    Cleopatra
# 1911     tt0001892               Den sorte drøm               Den sorte drøm
# 1906     tt0000574  The Story of the Kelly Gang  The Story of the Kelly Gang
#
#      date_published                    genre  duration           country  \
# year
# 1912     1912-11-13           Drama, History       100               USA
# 1911     1911-08-19                    Drama        53  Germany, Denmark
# 1906     1906-12-26  Biography, Crime, Drama        70         Australia
#
#      language            director                                 writer  ...  \
# year                                                                      ...
# 1912  English  Charles L. Gaskill                       Victorien Sardou  ...
# 1911      NaN           Urban Gad  Urban Gad, Gebhard Schätzler-Perasini  ...
# ...

# %%
df.set_index('year').sort_index(ascending=False).head(3)
# Out:
#      imdb_title_id              title     original_title date_published  \
# year
# 2019     tt9914286  Sokagin Çocuklari  Sokagin Çocuklari     2019-03-15
# 2019     tt7287656       Çat Kapi Ask       Çat Kapi Ask     2019-03-22
# 2019     tt7201744        Philophobia        Philophobia     2019-10-13
#
#                 genre  duration country language           director  \
# year
# 2019    Drama, Family        98  Turkey  Turkish  Ahmet Faik Akinci
# 2019  Comedy, Romance        92  Turkey  Turkish     Erhan Baytimur
# 2019            Drama       125      UK  English         Guy Davies
#
#                                  writer  ...  \
# year                                     ...
# 2019     Ahmet Faik Akinci, Kasim Uçkan  ...
# 2019  Deniz Güney Isintek, Nesrin Zamur  ...
# 2019        Matthew Brawley, Guy Davies  ...
#
#                                                  actors  \
# year
# 2019  Ahmet Faik Akinci, Belma Mamati, Metin Keçeci,...
# ...

# %%
new = df.set_index('year')

new.head(3)
# Out:
#      imdb_title_id                        title               original_title  \
# year
# 1906     tt0000574  The Story of the Kelly Gang  The Story of the Kelly Gang
# 1911     tt0001892               Den sorte drøm               Den sorte drøm
# 1912     tt0002101                    Cleopatra                    Cleopatra
#
#      date_published                    genre  duration           country  \
# year
# 1906     1906-12-26  Biography, Crime, Drama        70         Australia
# 1911     1911-08-19                    Drama        53  Germany, Denmark
# 1912     1912-11-13           Drama, History       100               USA
#
#      language            director                                 writer  ...  \
# year                                                                      ...
# 1906      NaN        Charles Tait                           Charles Tait  ...
# 1911      NaN           Urban Gad  Urban Gad, Gebhard Schätzler-Perasini  ...
# ...

# %%
new.reset_index().head(3)
# Out:
#    year imdb_title_id                        title  \
# 0  1906     tt0000574  The Story of the Kelly Gang
# 1  1911     tt0001892               Den sorte drøm
# 2  1912     tt0002101                    Cleopatra
#
#                 original_title date_published                    genre  \
# 0  The Story of the Kelly Gang     1906-12-26  Biography, Crime, Drama
# 1               Den sorte drøm     1911-08-19                    Drama
# 2                    Cleopatra     1912-11-13           Drama, History
#
#    duration           country language            director  ...  \
# 0        70         Australia      NaN        Charles Tait  ...
# 1        53  Germany, Denmark      NaN           Urban Gad  ...
# 2       100               USA  English  Charles L. Gaskill  ...
#
#                                               actors  \
# 0  Elizabeth Tait, John Tait, Norman Campbell, Be...
# 1  Asta Nielsen, Valdemar Psilander, Gunnar Helse...
# ...

# %%
# Topics to include 

s.str.contains()
s.str.startswith()
s.str.endswith()

s.dt.year month, day, dayofweek,
pd.to_datetime(series goes here)


# Filter, Sort, and Groupby
pd.isnull() | Checks for null Values, Returns Boolean Arrray
pd.notnull() | Opposite of pd.isnull()
df[df[col] > 0.5] | Rows where the column col is greater than 0.5
df[(df[col] > 0.5) & (df[col] < 0.7)] | Rows where 0.7 > col > 0.5
df.groupby(col) | Returns a groupby object for values from one column
df.groupby([col1,col2]) | Returns groupby object for values from multiple columns
df.groupby(col1)[col2] | Returns the mean of the values in col2, grouped by the values in col1 (mean can be replaced with almost any function from the statistics module)
df.pivot_table(index=col1,values=[col2,col3],aggfunc=mean) | Create a pivot table that groups by col1 and calculates the mean of col2 and col3
df.groupby(col1).agg(np.mean) | Find the average across all columns for every unique col1 group
df.apply(np.mean) | Apply the function np.mean() across each column
nf.apply(np.max,axis=1) | Apply the function np.max() across each row


Join/Combine
df1.append(df2) | Add the rows in df1 to the end of df2 (columns should be identical)
pd.concat([df1, df2],axis=1) | Add the columns in df1 to the end of df2 (rows should be identical)
df1.join(df2,on=col1,how='inner') | SQL-style join the columns in df1 with the columns on df2 where the rows for col have identical values. 'how' can be one of 'left', 'right', 'outer', 'inner'



Conditional renaming values based on filter df[df[year] == 1945 ['one', 'two']] = ['new', 'new2']


get_dummies
unstack
stack

group.size
group.sum
group.agg({})

multiindex


pd.concat([get_dummies])
